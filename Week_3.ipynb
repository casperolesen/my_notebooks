# %%
from my_modules.Week_3 import student_generator
# generate and save students

students_data = student_generator.generate_random_students(100)
student_generator.save_students_csv(students_data)
# Out:
# 100 students created!
# Saved to file!

# %%
# load students from generated csv file
data = student_generator.get_students_from_csv()

# %%
# print loaded students
for index, s in enumerate(data):
    print("{} {} {}".format( s.name, s.image_url, str(s.get_avg_grade()) ))
    if index == 20:
        break
# Out:
# Student 1 http://myprofile.com/myimage1.jpg 7.6
# Student 2 http://myprofile.com/myimage2.jpg 7.6
# Student 3 http://myprofile.com/myimage3.jpg 3.4
# Student 4 http://myprofile.com/myimage4.jpg 6.8
# Student 5 http://myprofile.com/myimage5.jpg 2.6
# Student 6 http://myprofile.com/myimage6.jpg 6.4
# Student 7 http://myprofile.com/myimage7.jpg 7.6
# Student 8 http://myprofile.com/myimage8.jpg 8.6
# Student 9 http://myprofile.com/myimage9.jpg 4.4
# Student 10 http://myprofile.com/myimage10.jpg 5.6
# Student 11 http://myprofile.com/myimage11.jpg 1.4
# Student 12 http://myprofile.com/myimage12.jpg 5.4
# Student 13 http://myprofile.com/myimage13.jpg 9.6
# Student 14 http://myprofile.com/myimage14.jpg 3.0
# Student 15 http://myprofile.com/myimage15.jpg 5.4
# Student 16 http://myprofile.com/myimage16.jpg 3.0
# Student 17 http://myprofile.com/myimage17.jpg 1.2
# Student 18 http://myprofile.com/myimage18.jpg 2.0
# Student 19 http://myprofile.com/myimage19.jpg 7.2
# ...

# %%
# print loaded data sorted by avg grade
students_sorted = sorted(data, key=lambda student: student.get_avg_grade(), reverse=True)
print("Sorted by grade:")
for index, s in enumerate(students_sorted):
    print("{} {} {}".format( s.name, s.image_url, str(s.get_avg_grade()) ))
    if index == 20:
        break
# Out:
# Sorted by grade:
# Student 13 http://myprofile.com/myimage13.jpg 9.6
# Student 68 http://myprofile.com/myimage68.jpg 9.0
# Student 8 http://myprofile.com/myimage8.jpg 8.6
# Student 32 http://myprofile.com/myimage32.jpg 8.6
# Student 39 http://myprofile.com/myimage39.jpg 8.6
# Student 61 http://myprofile.com/myimage61.jpg 8.6
# Student 75 http://myprofile.com/myimage75.jpg 8.6
# Student 69 http://myprofile.com/myimage69.jpg 8.4
# Student 97 http://myprofile.com/myimage97.jpg 8.4
# Student 77 http://myprofile.com/myimage77.jpg 8.2
# Student 64 http://myprofile.com/myimage64.jpg 7.8
# Student 1 http://myprofile.com/myimage1.jpg 7.6
# Student 2 http://myprofile.com/myimage2.jpg 7.6
# Student 7 http://myprofile.com/myimage7.jpg 7.6
# Student 30 http://myprofile.com/myimage30.jpg 7.6
# Student 46 http://myprofile.com/myimage46.jpg 7.6
# Student 54 http://myprofile.com/myimage54.jpg 7.6
# Student 70 http://myprofile.com/myimage70.jpg 7.4
# Student 19 http://myprofile.com/myimage19.jpg 7.2
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

names = [student.name for student in data]
grades = [student.get_avg_grade() for student in data]
plt.bar(names, grades, width=0.5, align='center')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 100 artists>

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
prog_dict = {}

for student in data:
    if student.get_study_progression() in prog_dict:
        prog_dict[student.get_study_progression()] += 1
    else:
        prog_dict[student.get_study_progression()] = 1
        
#prog = [print(student.get_study_progression()) for student in data]

max_y_key = max(prog_dict, key=prog_dict.get) #get key to the max value of a dictionary
#print(max_y_key)
max_y_val = prog_dict[max_y_key]
#print(max_y_val)

grades = list(prog_dict.keys())
students = list(prog_dict.values())
plt.bar(grades, students, width=0.1, align='center') # bar(x-vals, y-vals, bar width, align bar relative to x-val on x-axis)

plt.axis([0-0.1, 1+0.1, 0, max_y_val+5]) #axis(x-min, x-max, y-min, y-max)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-0.1, 1.1, 0.0, 45.0)
