# %%
import os
import pandas as pd
#file = os.system('wget -O unisex_navne.xls https://ast.dk/_namesdb/export/names?format=xls&gendermask=4')

df = pd.read_excel('https://ast.dk/_namesdb/export/names?format=xls&gendermask=4', header=None, names=['navne'])
names_list = list(df)
g = df.iterrows()
print(type(g))
for idx,row in g:
    print(row,'\n')
# Out:
# <class 'generator'>
# navne    Abel
# Name: 0, dtype: object
#
# navne    Abiola
# Name: 1, dtype: object
#
# navne    Acelya
# Name: 2, dtype: object
#
# navne    Ada
# Name: 3, dtype: object
#
# navne    Adama
# Name: 4, dtype: object
#
# navne    Adan
# Name: 5, dtype: object
#
# navne    Adar
# Name: 6, dtype: object
#
# navne    Addis
# Name: 7, dtype: object
#
# navne    Addison
# Name: 8, dtype: object
#
# navne    Aden
# Name: 9, dtype: object
#
# navne    Adi
# Name: 10, dtype: object
#
# navne    Adian
# Name: 11, dtype: object
#
# navne    Adita
# Name: 12, dtype: object
#
# navne    Aezha
# Name: 13, dtype: object
#
# navne    Afnan
# Name: 14, dtype: object
#
# navne    Agam
# Name: 15, dtype: object
#
# navne    Agne
# Name: 16, dtype: object
#
# navne    Ahsen
# Name: 17, dtype: object
#
# navne    Ahura
# Name: 18, dtype: object
#
# navne    Aidan
# Name: 19, dtype: object
#
# navne    Aiden
# Name: 20, dtype: object
#
# navne    Aiko
# Name: 21, dtype: object
#
# ...
